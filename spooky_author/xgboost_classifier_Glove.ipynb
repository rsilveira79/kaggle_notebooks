# %%
import pandas as pd
import numpy as np
import gensim
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, log_loss
from sklearn import preprocessing
import re
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
import xgboost as xgb

from tqdm import tqdm

nltk.download('stopwords')
nltk.download('punkt')
stops = set(stopwords.words('english'))
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package stopwords to /home/ubuntu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/ubuntu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /home/ubuntu/Envs/nlp/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
train = pd.read_csv('train.csv')
print(len(train))
train.head()
# Out:
# 19579
#         id                                               text author
# 0  id26305  This process, however, afforded me no means of...    EAP
# 1  id17569  It never once occurred to me that the fumbling...    HPL
# 2  id11008  In his left hand was a gold snuff box, from wh...    EAP
# 3  id27763  How lovely is spring As we looked from Windsor...    MWS
# 4  id12958  Finding nothing else, not even gold, the Super...    HPL

# %%
test = pd.read_csv('test.csv')
print(len(test))
test.head()
# Out:
# 8392
#         id                                               text
# 0  id02310  Still, as I urged our leaving Ireland with suc...
# 1  id24541  If a fire wanted fanning, it could readily be ...
# 2  id00134  And when they had broken down the frail door t...
# 3  id27757  While I was thinking how I should possibly man...
# 4  id04081  I am not sure to what limit his knowledge may ...

# %%
label_enconder = preprocessing.LabelEncoder()
label_enconder.fit(train['author'])
train['label_encoded'] = label_enconder.transform(train['author'])
train.head()
# Out:
#         id                                               text author  \
# 0  id26305  This process, however, afforded me no means of...    EAP
# 1  id17569  It never once occurred to me that the fumbling...    HPL
# 2  id11008  In his left hand was a gold snuff box, from wh...    EAP
# 3  id27763  How lovely is spring As we looked from Windsor...    MWS
# 4  id12958  Finding nothing else, not even gold, the Super...    HPL
#
#    label_encoded
# 0              0
# 1              1
# 2              0
# 3              2
# 4              1

# %% [markdown]
# ## Preprocessing function

# %%
def transformText(text):
    
    stops = set(stopwords.words("english"))
    
    # Convert text to lower
    text = text.lower()
    # Removing non ASCII chars    
    text = re.sub(r'[^\x00-\x7f]',r' ',text)
    
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    
    # Removing all the stopwords
    #filtered_words = [word for word in text.split() if word not in stops]
    filtered_words = [word for word in text.split()]

    # Removing all the tokens with lesser than 3 characters
    filtered_words = gensim.corpora.textcorpus.remove_short(filtered_words, minsize=3)
    
    # Preprocessed text after stop words removal
    text = " ".join(filtered_words)
    
    # Remove the punctuation
    text = gensim.parsing.preprocessing.strip_punctuation2(text)
    
    # Strip all the numerics
    text = gensim.parsing.preprocessing.strip_numeric(text)
    
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    
    # Stemming
    text = gensim.parsing.preprocessing.stem_text(text)
    return text

# %% [markdown]
# ## Creating preprocessing column on train and testing

# %%
train['text_processed']=train['text'].apply(lambda x: transformText(x))
train.tail()
# Out:
#             id                                               text author  \
# 19574  id17718  I could have fancied, while I looked at it, th...    EAP
# 19575  id08973  The lids clenched themselves together as if in...    EAP
# 19576  id05267  Mais il faut agir that is to say, a Frenchman ...    EAP
# 19577  id17513  For an item of news like this, it strikes us i...    EAP
# 19578  id00393  He laid a gnarled claw on my shoulder, and it ...    HPL
#
#        label_encoded                                     text_processed
# 19574              0  could have fanci while look it that some emin ...
# 19575              0               the lid clench themselv togeth spasm
# 19576              0  mai faut agir that sai frenchman never faint o...
# 19577              0  for item new like thi strike wa veri coolli re...
# 19578              1  laid gnarl claw shoulder and seem that it shak...

# %%
test['text_processed']=test['text'].apply(lambda x: transformText(x))
print(len(test))
test.tail()
# Out:
# 8392
#            id                                               text  \
# 8387  id11749         All this is now the fitter for my purpose.
# 8388  id10526                 I fixed myself on a wide solitude.
# 8389  id13477  It is easily understood that what might improv...
# 8390  id13761  Be this as it may, I now began to feel the ins...
# 8391  id04282  Long winded, statistical, and drearily genealo...
#
#                                          text_processed
# 8387                  all thi now the fitter for purpos
# 8388                            fix myself wide solitud
# 8389  easili understood that what might improv close...
# 8390  thi mai now began feel the inspir burn hope an...
# 8391  long wind statist and drearili genealog some t...

# %% [markdown]
# ## Train/Test split

# %%
x_train, x_test, y_train, y_test = train_test_split(train['text_processed'], train['label_encoded'], test_size = 0.2, random_state = 4)
true_label = np.array(y_test)
print("#" * 20 + " Some stats " + "#"*20)
print("Dataset training: {} uterances".format(x_train.shape[0]))
print("Dataset testing: {} uterances".format(x_test.shape[0]))
print("Different classes: {}".format(len(y_train.unique())))
# Out:
# #################### Some stats ####################
# Dataset training: 15663 uterances
# Dataset testing: 3916 uterances
# Different classes: 3

# %% [markdown]
# ## Loading Glove vectors as features

# %%
## Loading Glove vectors
embeddings_index = {}
f = open('../../vectors/glove.42B.300d.txt')
for line in tqdm(f):
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# 1917495it [07:07, 4480.89it/s]
# Found 1917495 word vectors.

# %%
print(embeddings_index['word'].shape)
embeddings_index['word']
# Out:
# (300,)
# array([ -1.31420001e-01,  -2.74459988e-01,   2.31170002e-03,
#          3.83850001e-02,  -4.46520001e-01,  -5.98660000e-02,
#         -3.34130001e+00,   5.85630000e-01,   4.86969985e-02,
#         -8.89739990e-02,   9.92240012e-02,  -1.87179998e-01,
#          1.64120004e-01,  -1.91770002e-01,  -6.05069995e-02,
#         -9.82039981e-03,  -2.91329995e-02,  -1.77550003e-01,
#          2.17209995e-01,   3.26810002e-01,  -1.12029999e-01,
#         -1.17569998e-01,   2.53160000e-02,   2.46380001e-01,
#          2.39759997e-01,   3.25869992e-02,  -1.62080005e-01,
#         -2.00859994e-01,   3.39760005e-01,  -8.54809999e-01,
#         -2.13070005e-01,  -3.86139989e-01,   1.61249995e-01,
#          7.11169988e-02,  -2.73689985e-01,  -9.66690015e-03,
#          1.70330003e-01,   5.04290015e-02,  -3.08050007e-01,
#         -2.93749988e-01,   1.34839997e-01,   4.98140007e-01,
#         -3.91119987e-01,   2.01810002e-02,   3.13430011e-01,
#         -9.30779986e-03,   6.50430024e-01,  -1.48819998e-01,
#          1.72390006e-02,  -9.71010029e-02,  -2.46060006e-02,
#         -3.04639995e-01,   3.90720010e-01,  -1.81329995e-01,
#          8.46820027e-02,   2.65060008e-01,  -1.82950005e-01,
#          5.41480005e-01,  -2.41190001e-01,  -8.18989992e-01,
#          3.76549989e-01,  -1.32970005e-01,   2.09089994e-01,
#         -2.52380013e-01,  -4.83709991e-01,   2.65529990e-01,
#          2.54810005e-01,  -2.78429990e-03,  -4.64839995e-01,
#          3.88990015e-01,  -1.69159994e-01,   2.55620003e-01,
#         -8.34549963e-02,  -8.35950002e-02,  -1.96700007e-01,
#          3.76960002e-02,  -1.30779997e-01,   4.05220002e-01,
#          2.39749998e-01,  -8.19069982e-01,  -5.78090012e-01,
#         -5.40899992e-01,   1.25650004e-01,  -3.62010002e-01,
#          3.02289993e-01,  -4.97070014e-01,  -5.75699985e-01,
#         -2.94259991e-02,  -1.67390004e-01,  -8.69619995e-02,
#         -3.28260005e-01,   1.72110006e-01,   2.16409996e-01,
#         -3.65720004e-01,  -6.31840006e-02,   5.28770030e-01,
#         -6.13420010e-02,   7.51190037e-02,  -6.40420020e-01,
#          1.32469997e-01,  -1.56859994e-01,   2.73440003e-01,
#         -1.62479997e-01,   3.64060014e-01,   3.27170014e-01,
#         -1.97980002e-01,   2.09370002e-01,  -2.39570007e-01,
#          1.00850001e-01,   1.60080001e-01,   1.00680001e-01,
#          2.13180006e-01,  -1.92939997e-01,   3.54070008e-01,
#         -2.87710011e-01,   1.39200002e-01,  -3.23190004e-01,
#         -5.02040029e-01,  -3.91610004e-02,  -1.94480002e-01,
#         -3.32940012e-01,  -1.85289994e-01,   3.73769999e-02,
#         -4.18769985e-01,  -1.06449999e-01,   2.43479997e-01,
#          4.05129999e-01,  -1.10650003e-01,  -6.91160023e-01,
#          3.87320012e-01,  -7.56229982e-02,   4.91629988e-02,
#          2.90039986e-01,   3.26909989e-01,  -9.65629965e-02,
#         -8.71739984e-02,   9.47329998e-02,   3.28070015e-01,
#         -3.20529997e-01,   7.01470017e-01,  -1.00759998e-01,
#         -1.04840003e-01,  -3.06819994e-02,  -2.10960001e-01,
#         -1.32280007e-01,   1.21540003e-01,   3.77740003e-02,
#          9.54960007e-03,   2.96719998e-01,   3.96439999e-01,
#         -2.48899996e-01,  -1.89630002e-01,  -1.39109999e-01,
#          8.16309974e-02,  -2.81029999e-01,   1.74539998e-01], dtype=float32)

# %%
# this function creates a normalized vector for the whole sentence
def sent2vec(s):
    words = str(s).lower()
    M = []
    for w in words:
        try:
            M.append(embeddings_index[w])
        except:
            continue
    M = np.array(M)
    v = M.sum(axis=0)
    if type(v) != np.ndarray:
        return np.zeros(300)
    return v / np.sqrt((v ** 2).sum())

# %%
## Create sentence vectors for the dataset
xtrain_glove = [sent2vec(x) for x in tqdm(x_train)]
xvalid_glove = [sent2vec(x) for x in tqdm(x_test)]
# Out:
#   0%|          | 0/15663 [00:00<?, ?it/s]
#   5%|▌         | 826/15663 [00:00<00:01, 8257.57it/s]
#  10%|█         | 1640/15663 [00:00<00:01, 8221.90it/s]
#  16%|█▌        | 2448/15663 [00:00<00:01, 8173.68it/s]
#  21%|██        | 3245/15663 [00:00<00:01, 8107.18it/s]
#  26%|██▌       | 4072/15663 [00:00<00:01, 8154.41it/s]
#  31%|███       | 4867/15663 [00:00<00:01, 8089.25it/s]
#  36%|███▌      | 5668/15663 [00:00<00:01, 8064.85it/s]
#  41%|████▏     | 6470/15663 [00:00<00:01, 8049.27it/s]
#  46%|████▋     | 7279/15663 [00:00<00:01, 8060.50it/s]
#  52%|█████▏    | 8078/15663 [00:01<00:00, 8035.80it/s]
#  57%|█████▋    | 8881/15663 [00:01<00:00, 8032.20it/s]
#  62%|██████▏   | 9705/15663 [00:01<00:00, 8091.84it/s]
#  67%|██████▋   | 10530/15663 [00:01<00:00, 8137.71it/s]
#  72%|███████▏  | 11355/15663 [00:01<00:00, 8168.82it/s]
#  78%|███████▊  | 12167/15663 [00:01<00:00, 8139.10it/s]
#  83%|████████▎ | 12986/15663 [00:01<00:00, 8152.50it/s]
#  88%|████████▊ | 13806/15663 [00:01<00:00, 8128.03it/s]
#  93%|█████████▎| 14632/15663 [00:01<00:00, 8166.71it/s]
#         -1.40436403e-02,   4.82000783e-02,  -1.71673968e-02,
#          9.89599037e-04,   1.08249066e-02,  -5.82180396e-02,
#         -1.20136328e-03,   2.13860422e-02,   4.17370945e-02,
#         -3.94904017e-02,   3.06693185e-02,  -9.62551404e-03,
#          4.98200655e-02,  -2.18573064e-02,  -6.50946843e-03,
#          1.06866062e-02,  -1.47795463e-02,   9.03500617e-03,
#          1.43578527e-02,   3.70536484e-02,   6.85345903e-02,
#         -2.24316902e-02,  -1.24809081e-02,   1.45305237e-02,
#          2.93690409e-03,   3.58727984e-02,   4.69130948e-02,
#          6.80411234e-03,  -3.10834660e-03,   3.75980623e-02,
#          5.86649496e-03,  -1.52508644e-02,   4.67340881e-03,
#         -1.38224484e-02,  -3.61599922e-02,   5.04056774e-02,
#          1.00017907e-02,  -9.92754102e-03,   1.03747630e-02,
#         -6.73738355e-03,   7.91230500e-02,  -4.17037457e-02], dtype=float32)

# %%
xtrain_glove = np.array(xtrain_glove)
xvalid_glove = np.array(xvalid_glove)

# %%
## Fitting a simple xgboost on glove features
clf = xgb.XGBClassifier(nthread=10, silent=False)
clf.fit(xtrain_glove, y_train)
preds_proba = clf.predict_proba(xvalid_glove)

# %%
print ("logloss: %0.3f " % log_loss(true_label, preds_proba))
# Out:
# logloss: 1.008

# %%
## Testing XGBoost with Glove Features
clf = xgb.XGBClassifier(max_depth=5, n_estimators=1000, colsample_bytree=0.8, 
                        subsample=0.8, nthread=10, learning_rate=0.1)
eval_set = [(xvalid_glove,y_test)]
clf.fit(xtrain_glove, y_train, eval_metric = "mlogloss", eval_set=eval_set, verbose=True)
preds_proba = clf.predict_proba(xvalid_glove)
preds = clf.predict(xvalid_glove)
# Out:
# [0]	validation_0-mlogloss:1.09052
# [1]	validation_0-mlogloss:1.08306
# [2]	validation_0-mlogloss:1.07592
# [3]	validation_0-mlogloss:1.06999
# [4]	validation_0-mlogloss:1.06424
# [5]	validation_0-mlogloss:1.05924
# [6]	validation_0-mlogloss:1.05485
# [7]	validation_0-mlogloss:1.05068
# [8]	validation_0-mlogloss:1.04716
# [9]	validation_0-mlogloss:1.04395
# [10]	validation_0-mlogloss:1.04112
# [11]	validation_0-mlogloss:1.03832
# [12]	validation_0-mlogloss:1.03531
# [13]	validation_0-mlogloss:1.03275
# [14]	validation_0-mlogloss:1.0311
# [15]	validation_0-mlogloss:1.02914
# [16]	validation_0-mlogloss:1.0271
# [17]	validation_0-mlogloss:1.02612
# [18]	validation_0-mlogloss:1.02464
# [19]	validation_0-mlogloss:1.02296
# [20]	validation_0-mlogloss:1.02128
# [21]	validation_0-mlogloss:1.0197
# [22]	validation_0-mlogloss:1.01879
# [23]	validation_0-mlogloss:1.01755
# [24]	validation_0-mlogloss:1.01662
# [25]	validation_0-mlogloss:1.01585
# [26]	validation_0-mlogloss:1.01506
# [27]	validation_0-mlogloss:1.0141
# [28]	validation_0-mlogloss:1.01399
# [29]	validation_0-mlogloss:1.01308
# [30]	validation_0-mlogloss:1.01248
# [31]	validation_0-mlogloss:1.01212
# [32]	validation_0-mlogloss:1.01161
# [33]	validation_0-mlogloss:1.01086
# [34]	validation_0-mlogloss:1.01004
# [35]	validation_0-mlogloss:1.00969
# [36]	validation_0-mlogloss:1.00926
# [37]	validation_0-mlogloss:1.00877
# [38]	validation_0-mlogloss:1.00823
# [39]	validation_0-mlogloss:1.00772
# [40]	validation_0-mlogloss:1.00709
# [41]	validation_0-mlogloss:1.00665
# [42]	validation_0-mlogloss:1.00629
# [43]	validation_0-mlogloss:1.00598
# [44]	validation_0-mlogloss:1.00578
# [45]	validation_0-mlogloss:1.00548
# [46]	validation_0-mlogloss:1.00492
# [47]	validation_0-mlogloss:1.0045
# [48]	validation_0-mlogloss:1.0042
# [49]	validation_0-mlogloss:1.00373
# [50]	validation_0-mlogloss:1.00349
# [51]	validation_0-mlogloss:1.00326
# [52]	validation_0-mlogloss:1.00335
# [53]	validation_0-mlogloss:1.00343
# [54]	validation_0-mlogloss:1.00341
# [55]	validation_0-mlogloss:1.00334
# [56]	validation_0-mlogloss:1.00336
# [57]	validation_0-mlogloss:1.00302
# [58]	validation_0-mlogloss:1.00272
# [59]	validation_0-mlogloss:1.00268
# [60]	validation_0-mlogloss:1.00303
# [61]	validation_0-mlogloss:1.00311
# [62]	validation_0-mlogloss:1.00314
# [63]	validation_0-mlogloss:1.00313
# [64]	validation_0-mlogloss:1.00301
# [65]	validation_0-mlogloss:1.00261
# [66]	validation_0-mlogloss:1.00256
# [67]	validation_0-mlogloss:1.00251
# [68]	validation_0-mlogloss:1.00284
# [69]	validation_0-mlogloss:1.00286
# [70]	validation_0-mlogloss:1.00278
# [71]	validation_0-mlogloss:1.00264
# [72]	validation_0-mlogloss:1.00252
# [73]	validation_0-mlogloss:1.00251
# [74]	validation_0-mlogloss:1.00239
# [75]	validation_0-mlogloss:1.00244
# [76]	validation_0-mlogloss:1.00243
# [77]	validation_0-mlogloss:1.00269
# [78]	validation_0-mlogloss:1.0029
# [79]	validation_0-mlogloss:1.00285
# [80]	validation_0-mlogloss:1.0028
# [81]	validation_0-mlogloss:1.00257
# [82]	validation_0-mlogloss:1.00257
# [83]	validation_0-mlogloss:1.00235
# [84]	validation_0-mlogloss:1.00208
# [85]	validation_0-mlogloss:1.00247
# [86]	validation_0-mlogloss:1.0022
# [87]	validation_0-mlogloss:1.00196
# [88]	validation_0-mlogloss:1.00195
# [89]	validation_0-mlogloss:1.00222
# [90]	validation_0-mlogloss:1.002
# [91]	validation_0-mlogloss:1.00182
# [92]	validation_0-mlogloss:1.0017
# [93]	validation_0-mlogloss:1.0017
# [94]	validation_0-mlogloss:1.00169
# [95]	validation_0-mlogloss:1.0017
# [96]	validation_0-mlogloss:1.00186
# [97]	validation_0-mlogloss:1.00214
# [98]	validation_0-mlogloss:1.00211
# [99]	validation_0-mlogloss:1.00197
# [100]	validation_0-mlogloss:1.0019
# [101]	validation_0-mlogloss:1.00185
# [102]	validation_0-mlogloss:1.00188
# [103]	validation_0-mlogloss:1.00192
# [104]	validation_0-mlogloss:1.00212
# [105]	validation_0-mlogloss:1.00203
# [106]	validation_0-mlogloss:1.00222
# [107]	validation_0-mlogloss:1.00176
# [108]	validation_0-mlogloss:1.00157
# [109]	validation_0-mlogloss:1.0015
# [110]	validation_0-mlogloss:1.00125
# [111]	validation_0-mlogloss:1.00136
# [112]	validation_0-mlogloss:1.00122
# [113]	validation_0-mlogloss:1.00143
# [114]	validation_0-mlogloss:1.00123
# [115]	validation_0-mlogloss:1.00126
# [116]	validation_0-mlogloss:1.00096
# [117]	validation_0-mlogloss:1.00108
# [118]	validation_0-mlogloss:1.00143
# [119]	validation_0-mlogloss:1.00155
# [120]	validation_0-mlogloss:1.0017
# [121]	validation_0-mlogloss:1.0016
# [122]	validation_0-mlogloss:1.00148
# [123]	validation_0-mlogloss:1.00154
# [124]	validation_0-mlogloss:1.00164
# [125]	validation_0-mlogloss:1.00157
# [126]	validation_0-mlogloss:1.00169
# [127]	validation_0-mlogloss:1.00159
# [128]	validation_0-mlogloss:1.0014
# [129]	validation_0-mlogloss:1.00167
# [130]	validation_0-mlogloss:1.00144
# [131]	validation_0-mlogloss:1.0016
# [132]	validation_0-mlogloss:1.00157
# [133]	validation_0-mlogloss:1.00157
# [134]	validation_0-mlogloss:1.00159
# [135]	validation_0-mlogloss:1.00177
# [136]	validation_0-mlogloss:1.00169
# [137]	validation_0-mlogloss:1.00173
# [138]	validation_0-mlogloss:1.00134
# [139]	validation_0-mlogloss:1.00122
# [140]	validation_0-mlogloss:1.00147
# [141]	validation_0-mlogloss:1.00165
# [142]	validation_0-mlogloss:1.00182
# [143]	validation_0-mlogloss:1.00175
# [144]	validation_0-mlogloss:1.00171
# [145]	validation_0-mlogloss:1.00181
# [146]	validation_0-mlogloss:1.00215
# [147]	validation_0-mlogloss:1.00218
# [148]	validation_0-mlogloss:1.00229
# [149]	validation_0-mlogloss:1.0025
# [150]	validation_0-mlogloss:1.00249
# [151]	validation_0-mlogloss:1.00231
# [152]	validation_0-mlogloss:1.00215
# [153]	validation_0-mlogloss:1.00235
# [154]	validation_0-mlogloss:1.00231
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-06b902a6ae37> in <module>()
#       3                         subsample=0.8, nthread=10, learning_rate=0.1)
#       4 eval_set = [(xvalid_glove,y_test)]
# ----> 5 clf.fit(xtrain_glove, y_train, eval_metric = "mlogloss", eval_set=eval_set, verbose=True)
#       6 preds_proba = clf.predict_proba(xvalid_glove)
#       7 preds = clf.predict(xvalid_glove)
#
# ~/Envs/nlp/lib/python3.5/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose)
#     443                               early_stopping_rounds=early_stopping_rounds,
#     444                               evals_result=evals_result, obj=obj, feval=feval,
# --> 445                               verbose_eval=verbose)
#     446
#     447         self.objective = xgb_options["objective"]
#
# ~/Envs/nlp/lib/python3.5/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, learning_rates, xgb_model, callbacks)
#     203                            evals=evals,
#     204                            obj=obj, feval=feval,
# --> 205                            xgb_model=xgb_model, callbacks=callbacks)
#     206
#     207
#
# ~/Envs/nlp/lib/python3.5/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      74         # Skip the first update if it is a recovery step.
#      75         if version % 2 == 0:
# ---> 76             bst.update(dtrain, i, obj)
#      77             bst.save_rabit_checkpoint()
#      78             version += 1
#
# ~/Envs/nlp/lib/python3.5/site-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#     804
#     805         if fobj is None:
# --> 806             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, iteration, dtrain.handle))
#     807         else:
#     808             pred = self.predict(dtrain)
#
# KeyboardInterrupt:
